# %%
import instaloader
import pandas as pd

def extract_comments(post_url, limit=100):
    # Create an instance of Instaloader
    loader = instaloader.Instaloader()
    loader.login(user="tps_1514", passwd="Tanmay@2004*")

    try:
        # Load the post by its URL
        post = instaloader.Post.from_shortcode(loader.context, post_url.split('/')[-2])
        
        # Initialize lists to store comments and usernames
        comments_list = []
        usernames_list = []
        
        # Counter for limiting the number of comments
        count = 0
        
        # Iterate over comments and store them in lists
        for comment in post.get_comments():
            comments_list.append(comment.text)
            usernames_list.append(comment.owner.username)  # Accessing the username through owner
            
            # Increment the counter
            count += 1
            
            # Break the loop if the limit is reached
            if count >= limit:
                break
        
        # Create a DataFrame
        df = pd.DataFrame({'Username': usernames_list, 'Comment': comments_list})
        
        return df
        
    except Exception as e:
        print("Error:", e)

# Example usage
post_url = 'https://www.instagram.com/p/C3HTzhsLrSh/?igsh=MTcxMnZ1dHI4b3l1Mg%3D%3D&img_index=1'
comments_df = extract_comments(post_url, limit=100)

# Print the DataFrame
comments_df
# Out:
# C:\Users\Tanmay\AppData\Local\Temp\ipykernel_17040\3702466019.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#             Username                                            Comment
# 0      kyayaaarapurv  another day to comment "not all of them, but i...
# 1     bruce_wayne_54                                            ☪️ancer
# 2      fantasy4shoes  Only yogi ji knows how  to handle these zombies .
# 3   artbykabirhirani            Victim card being played in 3.. 2.. 1..
# 4           mr.ydv8_                                Peaceful activities
# ..               ...                                                ...
# 95      mr.peace_09_                                        Nuke kardo😂
# 96         ishap7121  Police walo ki galti hai.....jab shoot at sigh...
# 97  jai_maa_bharatii                        They need bjpoo gormint cm🤡
# 98          paapinet  Pehele Govts khud settled krwati hein \nFr Hin...
# 99  shreyas__reddy__                                  Pissfull Chuslims
#
# [100 rows x 2 columns]

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\tanmay\appdata\roaming\python\python312\site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\tanmay\appdata\roaming\python\python312\site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tanmay\appdata\roaming\python\python312\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tanmay\appdata\roaming\python\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tanmay\appdata\roaming\python\python312\site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\tanmay\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
