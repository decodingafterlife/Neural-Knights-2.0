# %%
# !pip install pandas
# !pip install youtube_transcript_api
# !pip install instaloader
# !pip install google-api-python-client
# !pip install youtube_transcript_api
# Out:
# Requirement already satisfied: pandas in c:\users\tanmay\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tanmay\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tanmay\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\tanmay\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\tanmay\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\tanmay\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: youtube_transcript_api in c:\users\tanmay\anaconda3\lib\site-packages (0.6.2)
# Requirement already satisfied: requests in c:\users\tanmay\anaconda3\lib\site-packages (from youtube_transcript_api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tanmay\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tanmay\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tanmay\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tanmay\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (2023.7.22)
# Requirement already satisfied: instaloader in c:\users\tanmay\anaconda3\lib\site-packages (4.10.3)
# Requirement already satisfied: requests>=2.4 in c:\users\tanmay\anaconda3\lib\site-packages (from instaloader) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tanmay\anaconda3\lib\site-packages (from requests>=2.4->instaloader) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tanmay\anaconda3\lib\site-packages (from requests>=2.4->instaloader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tanmay\anaconda3\lib\site-packages (from requests>=2.4->instaloader) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tanmay\anaconda3\lib\site-packages (from requests>=2.4->instaloader) (2023.7.22)
# Requirement already satisfied: google-api-python-client in c:\users\tanmay\anaconda3\lib\site-packages (2.116.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in c:\users\tanmay\anaconda3\lib\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in c:\users\tanmay\anaconda3\lib\site-packages (from google-api-python-client) (2.27.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\tanmay\anaconda3\lib\site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\tanmay\anaconda3\lib\site-packages (from google-api-python-client) (2.16.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\tanmay\anaconda3\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\tanmay\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.62.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\tanmay\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.23.4)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\tanmay\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\tanmay\anaconda3\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tanmay\anaconda3\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\tanmay\anaconda3\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\tanmay\anaconda3\lib\site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\tanmay\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tanmay\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tanmay\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tanmay\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tanmay\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.7.22)
# Requirement already satisfied: youtube_transcript_api in c:\users\tanmay\anaconda3\lib\site-packages (0.6.2)
# Requirement already satisfied: requests in c:\users\tanmay\anaconda3\lib\site-packages (from youtube_transcript_api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tanmay\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tanmay\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tanmay\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tanmay\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (2023.7.22)

# %%
import instaloader
from googleapiclient.discovery import build
import pandas as pd
import re
from urllib.parse import urlparse
from youtube_transcript_api import YouTubeTranscriptApi

def extract_comments_from_url(url, limit=100):
    # Parse the URL to identify the platform
    parsed_url = urlparse(url)
    domain = parsed_url.netloc
    if domain == 'www.instagram.com':
        # Extract comments from Instagram
        return extract_instagram_comments(url, limit)
    elif domain == 'www.youtube.com':
        # Extract comments from YouTube
        video_id = get_video_id(url)
        if video_id:
            return extract_youtube_comments(video_id, limit)
        else:
            print("Invalid YouTube URL.")
            return None
    else:
        print("Unsupported platform.")
        return None

def extract_instagram_comments(post_url, limit=100):
    # Create an instance of Instaloader
    loader = instaloader.Instaloader()
    loader.login(user="***", passwd="****")

    try:
        # Load the post by its URL
        post = instaloader.Post.from_shortcode(loader.context, post_url.split('/')[-2])
        
        # Initialize lists to store comments and usernames
        comments_list = []
        usernames_list = []
        
        # Counter for limiting the number of comments
        count = 0
        
        # Iterate over comments and store them in lists
        for comment in post.get_comments():
            comments_list.append(comment.text)
            usernames_list.append(comment.owner.username)  # Accessing the username through owner
            
            # Increment the counter
            count += 1
            
            # Break the loop if the limit is reached
            if count >= limit:
                break
        
        # Create a DataFrame
        df = pd.DataFrame({'Username': usernames_list, 'Comment': comments_list})
        
        return df
        
    except Exception as e:
        print("Error:", e)

def get_video_id(youtube_url):
    # Regular expression pattern to match YouTube video IDs
    pattern = r"(?<=v=)[a-zA-Z0-9_-]+(?=&|\?|$)"
    match = re.search(pattern, youtube_url)
    if match:
        return match.group(0)
    else:
        return None

def extract_youtube_comments(video_id, limit=100):
    # Initialize the YouTube API client
    api_key = "***"
    youtube = build('youtube', 'v3', developerKey=api_key)

    # Set up the initial API request
    request = youtube.commentThreads().list(part="snippet,replies", videoId=video_id, textFormat="plainText", maxResults=100)

    # Lists to store comments, replies, user names, dates, and comment likes
    comments = []
    replies_list = []
    user_names = []
    dates = []
    comment_likes = []

    # Fetch comments in a loop until at least 100 comments are retrieved or there are no more comments
    while len(comments) < limit and request:
        try:
            # Execute the API request
            response = request.execute()

            # Iterate through the response items
            for item in response['items']:
                # Extract comment details
                comment_snippet = item['snippet']['topLevelComment']['snippet']
                if len(comment_snippet['textDisplay']) > 128:
                    continue

                comments.append(comment_snippet['textDisplay'])
                user_names.append(comment_snippet['authorDisplayName'])
                dates.append(comment_snippet['publishedAt'])

                # Extract comment likes
                comment_likes.append(comment_snippet.get('likeCount', 0))

                # Extract replies if available
                reply_count = item['snippet']['totalReplyCount']
                if reply_count > 0:
                    replies = [reply['snippet']['textDisplay'] for reply in item['replies']['comments']]
                else:
                    replies = []
                replies_list.append(replies)

            # Check if there are more pages of comments
            request = youtube.commentThreads().list_next(request, response)

            # Check if the limit has been reached
            if len(comments) >= limit:
                break

        except Exception as e:
            print(f"An error occurred: {str(e)}")
            break

    # Create a DataFrame from the collected data
    df = pd.DataFrame({"comment": comments[:limit], "user_name": user_names[:limit], "date": dates[:limit]})
    
    try:
        transcript = YouTubeTranscriptApi.get_transcript(video_id)
        print("\nTranscript:")
        for segment in transcript:
            print(segment['text'])
    except Exception as e:
        print(f"Failed to fetch transcript: {str(e)}")
    
    return df

# %%
url = "https://www.youtube.com/watch?v=77hrMO0ZarU"

extract_comments_from_url(url, limit=100)
# Out:
# Transcript:
# [{'text': "i'm trapping my friend's bed so that", 'start': 0.08, 'duration': 3.68}, {'text': 'whenever he respawns he falls through', 'start': 1.599, 'duration': 4.081}, {'text': 'the bedrock and into the void you see', 'start': 3.76, 'duration': 4.159}, {'text': 'last week he pretended to be on my team', 'start': 5.68, 'duration': 4.72}, {'text': 'in the secret face war only to betray me', 'start': 7.919, 'duration': 4.481}, {'text': 'and steal my enchanted golden apple', 'start': 10.4, 'duration': 3.84}, {'text': 'steve for this to work i need his bed', 'start': 12.4, 'duration': 3.6}, {'text': 'location but since he used an enderpearl', 'start': 14.24, 'duration': 4.56}, {'text': 'stasis chamber to rob me i had no idea', 'start': 16.0, 'duration': 4.24}, {'text': 'where his bed could be i searched all', 'start': 18.8, 'duration': 3.84}, {'text': 'around the server with no luck until i', 'start': 20.24, 'duration': 4.48}, {'text': 'ran into his teammate branzie in the', 'start': 22.64, 'duration': 3.6}, {'text': 'nether are you going through this portal', 'start': 24.72, 'duration': 3.6}, {'text': 'too oh are you going this way i was', 'start': 26.24, 'duration': 4.08}, {'text': "actually not going that way what that's", 'start': 28.32, 'duration': 3.279}, {'text': "crazy you're not going through that", 'start': 30.32, 'duration': 3.04}, {'text': 'portal wow and this was perfect because', 'start': 31.599, 'duration': 3.521}, {'text': 'the whole time i was in a call with my', 'start': 33.36, 'duration': 3.68}, {'text': 'friend siv who had a spectator account', 'start': 35.12, 'duration': 4.24}, {'text': 'meaning that if i kill branzie civ could', 'start': 37.04, 'duration': 4.32}, {'text': "find his bed location but i didn't just", 'start': 39.36, 'duration': 4.0}, {'text': 'want branzy i wanted them both there so', 'start': 41.36, 'duration': 4.24}, {'text': 'i stalled i pretended to be interested', 'start': 43.36, 'duration': 4.16}, {'text': 'in negotiating and right on schedule', 'start': 45.6, 'duration': 3.92}, {'text': 'chief showed up to assassinate me with', 'start': 47.52, 'duration': 3.519}, {'text': 'some potions i made a quick work of him', 'start': 49.52, 'duration': 3.679}, {'text': "both and that's when civ found their", 'start': 51.039, 'duration': 4.16}, {'text': 'secret base so i waited until they both', 'start': 53.199, 'duration': 5.761}, {'text': 'came back to get their stuff all right', 'start': 55.199, 'duration': 3.761}, {'text': 'go down to the end that one on your left', 'start': 60.8, 'duration': 3.6}, {'text': "i don't know how to get to it there you", 'start': 62.64, 'duration': 3.68}, {'text': 'go i found their secret base but there', 'start': 64.4, 'duration': 3.759}, {'text': 'was no bed which was weird because civ', 'start': 66.32, 'duration': 3.76}, {'text': 'followed him shortly after he respawned', 'start': 68.159, 'duration': 3.441}, {'text': 'so the bed must be close but there was', 'start': 70.08, 'duration': 2.96}, {'text': 'more pressing matters at hand the day', 'start': 71.6, 'duration': 3.28}, {'text': 'before me and chief found all of', 'start': 73.04, 'duration': 3.84}, {'text': "ramsay's items then hid them underground", 'start': 74.88, 'duration': 4.16}, {'text': 'but uh chief kind of betrayed me so i', 'start': 76.88, 'duration': 3.919}, {'text': 'needed to re-hide the items that was the', 'start': 79.04, 'duration': 3.68}, {'text': 'only leverage i had against these guys', 'start': 80.799, 'duration': 4.081}, {'text': 'but guess who showed up it was branzy i', 'start': 82.72, 'duration': 3.52}, {'text': "was surprised he didn't break in", 'start': 84.88, 'duration': 3.279}, {'text': 'immediately and steal all his stuff back', 'start': 86.24, 'duration': 3.519}, {'text': 'branzie should know where the stuff is', 'start': 88.159, 'duration': 3.361}, {'text': 'because chief just joined his team but', 'start': 89.759, 'duration': 3.601}, {'text': "by some miracle he didn't check a ...
#                                               comment          user_name  \
# 0            Consider Subscribing if ya like the vid!           @rekrap2
# 1             Team rekrap is more smart then Einstine    @III_Gaming3112
# 2   Spoilers: the voidtrap didn't actually work an...  @erikpillosko3829
# 3                          Isn’t deepslate coal rare😅      @BagMan_Games
# 4                      I'm the biggest rekrapper ever         @45TR4L1TY
# ..                                                ...                ...
# 95  Ryan Reynolds and Matt Damon team up against a...         @hacksarch
# 96                                                  Ü          @sam74775
# 97                                                 Hi     @justinham5000
# 98       Me watching all the channels’ videos of this      @meepruns4636
# 99     1.32 mil, thats the same number as my name lol          @DrSullyD
#
#                     date
# 0   2021-11-28T16:14:10Z
# 1   2024-02-05T12:26:42Z
# 2   2024-02-04T06:03:44Z
# 3   2024-01-17T22:38:41Z
# 4   2024-01-07T06:59:22Z
# ..                   ...
# 95  2023-04-06T08:31:34Z
# 96  2023-04-04T13:19:15Z
# 97  2023-04-02T21:43:55Z
# 98  2023-04-02T03:56:54Z
# 99  2023-04-01T08:06:17Z
#
# [100 rows x 3 columns]
