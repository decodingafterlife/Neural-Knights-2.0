# %%
pip install youtube-transcript-api
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: youtube-transcript-api in c:\users\tanmay\appdata\roaming\python\python312\site-packages (0.6.2)
# Requirement already satisfied: requests in c:\users\tanmay\appdata\roaming\python\python312\site-packages (from youtube-transcript-api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tanmay\appdata\roaming\python\python312\site-packages (from requests->youtube-transcript-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tanmay\appdata\roaming\python\python312\site-packages (from requests->youtube-transcript-api) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tanmay\appdata\roaming\python\python312\site-packages (from requests->youtube-transcript-api) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tanmay\appdata\roaming\python\python312\site-packages (from requests->youtube-transcript-api) (2024.2.2)

# %%
video_id = 'ytduid5s4Nw'
from youtube_transcript_api import YouTubeTranscriptApi

YouTubeTranscriptApi.get_transcript(video_id)
# Out:
# [{'text': 'so I coded the Minecraft world to be',
#   'start': 0.0,
#   'duration': 4.14},
#  {'text': 'completely underwater including the',
#   'start': 1.92,
#   'duration': 4.859},
#  {'text': 'Nether and End well the end islands are',
#   'start': 4.14,
#   'duration': 5.1},
#  {'text': 'islands for a reason now and I invited',
#   'start': 6.779,
#   'duration': 4.141},
#  {'text': 'my friend to play with me who is a squid',
#   'start': 9.24,
#   'duration': 3.3},
#  {'text': 'conveniently to see if we could not only',
#   'start': 10.92,
#   'duration': 3.839},
#  {'text': 'beat the game but get an elytra all',
#   'start': 12.54,
#   'duration': 4.8},
#  {'text': 'starting from nothing drowning in the',
#   'start': 14.759,
#   'duration': 4.561},
#  {'text': 'middle of an ocean okay go go go go go',
#   'start': 17.34,
#   'duration': 4.439},
#  {'text': 'go go go go go Chief follow me follow me',
#   'start': 19.32,
#   'duration': 6.18},
#  {'text': "we don't have much time I am losing so",
#   'start': 21.779,
#   'duration': 5.461},
#  {'text': "much air fine it's fine you remember",
#   'start': 25.5,
#   'duration': 4.82},
#  {'text': 'your training you remember training yeah',
#   'start': 27.24,
#   'duration': 5.46},
#  {'text': 'quick okay quickly come in the ship come',
#   'start': 30.32,
#   'duration': 3.52},
#  {'text': 'the ship come in the ship coming yeah',
#   'start': 32.7,
#   'duration': 3.18},
#  {'text': 'yeah yeah yeah yeah okay get in the car',
#   'start': 33.84,
#   'duration': 3.12},
#  {'text': 'get in the pressure plate get the',
#   'start': 35.88,
#   'duration': 2.94},
#  {'text': "pressure breathing yeah I'm breathing",
#   'start': 36.96,
#   'duration': 5.099},
#  {'text': "I'm breathing okay that was intense",
#   'start': 38.82,
#   'duration': 6.0},
#  {'text': 'anyways welcome to my underwater world',
#   'start': 42.059,
#   'duration': 4.561},
#  {'text': "Chief isn't it cool", 'start': 44.82, 'duration': 4.02},
#  {'text': "I'm ready to leave I really didn't have",
#   'start': 46.62,
#   'duration': 3.72},
#  {'text': 'a plan after this we should probably',
#   'start': 48.84,
#   'duration': 3.48},
#  {'text': 'just like get some wood yeah I think we',
#   'start': 50.34,
#   'duration': 3.899},
#  {'text': "can reach some wood okay I'm gonna take",
#   'start': 52.32,
#   'duration': 4.86},
#  {'text': 'my pressure plate and go up to this log',
#   'start': 54.239,
#   'duration': 4.34},
#  {'text': 'over here', 'start': 57.18, 'duration': 3.899},
#  {'text': "oh my God puffer fish dude there's a",
#   'start': 58.579,
#   'duration': 4.841},
#  {'text': "puffer fish There's an actual puffer",
#   'start': 61.079,
#   'duration': 4.321},
#  {'text': 'fish here oh my God where did he come',
#   'start': 63.42,
#   'duration': 4.379},
#  {'text': 'from that they just spawn in this biome',
#   'start': 65.4,
#   'duration': 4.8},
#  {'text': "man you're kidding dude there's a",
#   'start': 67.799,
#   'duration': 4.921},
#  {'text': "trident guy who's a dragon guy follow me",
#   'start': 70.2,
#   'duration': 4.38},
#  {'text': "follow me follow me follow me that's",
#   'start': 72.72,
#   'duration': 3.96},
#  {'text': "right this way there's a door right over",
#   'start': 74.58,
#   'duration': 3.719},
#  {'text': "here we gotta make it to the door I'm",
#   'start': 76.68,
#   'duration': 4.439},
#  {'text': 'squid not a fighter pilot', 'start': 78.299, 'duration': 4.021},
#  {'text': "um well it's a good thing this isn't",
#   'start': 81.119,
#   'duration': 2.64},
#  {'text': 'hardcore otherwise that would have been',
#   'start': 82.32,
#   'duration': 3.42},
#  {'text': "a short Chief adventure oh oh you're",
#   'start': 83.759,
#   'duration': 4.321},
#  {'text': 'taking damage you can make it you can',
#   'start': 85.74,
#   'duration': 4.98},
#  {'text': 'make it okay okay get in the door get in',
#   'start': 88.08,
#   'duration': 3.78},
#  {'text': 'the door get in the door get in the door',
#   'start': 90.72,
#   'duration': 3.86},
#  {'text': 'oh my gosh', 'start': 91.86, 'duration': 2.72},
#  {'text': "what's the game plan we got a bear",
#   'start': 94.759,
#   'duration': 3.581},
#  {'text': 'treasure map', 'start': 96.659, 'duration': 3.541},
#  {'text': "I don't think that's gonna be very",
#   'start': 98.34,
#   'duration': 5.3},
#  {'text': 'useful wow this is really helpful',
#   'start': 100.2,
#   'duration': 5.7},
#  {'text': "and we're leaving well hold on the berry",
#   'start': 103.64,
#   'duration': 3.82},
#  {'text': 'treasure map says we should go the other',
#   'start': 105.9,
#   'duration': 4.259},
#  {'text': 'way wait does it have an x on it no I',
#   'start': 107.46,
#   'duration': 5.46},
#  {'text': 'was kidding at this point we really',
#   'start': 110.159,
#   'duration': 5.341},
#  {'text': 'needed food and since Chief is a squid I',
#   'start': 112.92,
#   'duration': 4.08},
#  {'text': "figured I'd ask him where should we go",
#   'start': 115.5,
#   'duration': 3.479},
#  {'text': 'for shipwrecks oh I see this is why',
#   'start': 117.0,
#   'duration': 3.72},
#  {'text': "you've asked for my expertise well I'm",
#   'start': 118.979,
#   'duration': 3.361},
#  {'text': 'gonna have to ask you to pull up the F3',
#   'start': 120.72,
#   'duration': 3.359},
#  {'text': 'screen for a moment okay this is going',
#   'start': 122.34,
#   'duration': 4.139},
#  {'text': 'to be a technical trick yep so if you',
#   'start': 124.079,
#   'duration': 5.04},
#  {'text': "hit shift F3 yeah that'll bring up the",
#   'start': 126.479,
#   'duration': 4.741},
#  {'text': 'debugging pie chart menu and from there',
#   'start': 129.119,
#   'duration': 4.921},
#  {'text': 'we close it out with F3 we pull the sand',
#   'start': 131.22,
#   'duration': 5.06},
#  {'text': 'out and we just wing it', 'start': 134.04, 'duration': 4.62},
#  {'text': "okay we're gonna break over here we're",
#   'start': 136.28,
#   'duration': 4.179},
#  {'text': 'gonna just try to go through this Chasm',
#   'start': 138.66,
#   'duration': 4.38},
#  {'text': "I have a feeling there's gonna be",
#   'start': 140.459,
#   'duration': 5.041},
#  {'text': "something else and I'm right oh ruined",
#   'start': 143.04,
#   'duration': 4.62},
#  {'text': 'portal wait an underwater ruined portal',
#   'start': 145.5,
#   'duration': 4.56},
#  {'text': 'what oh wait until you see the nether',
#   'start': 147.66,
#   'duration': 4.26},
#  {'text': "man oh my god I didn't even think of it",
#   'start': 150.06,
#   'duration': 4.44},
#  {'text': 'I have I am so excited and the end',
#   'start': 151.92,
#   'duration': 4.8},
#  {'text': 'Dimension the end Dimension too and the',
#   'start': 154.5,
#   'duration': 4.319},
#  {'text': "eighth I'm just kidding and the Aether",
#   'start': 156.72,
#   'duration': 4.799},
#  {'text': "well I don't see a buried treasure",
#   'start': 158.819,
#   'duration': 5.661},
#  {'text': "um so I'm just gonna keep on going okay",
#   'start': 161.519,
#   'duration': 5.761},
#  {'text': "I got emeralds hey I'm going for the",
#   'start': 164.48,
#   'duration': 4.96},
#  {'text': 'berry treasure map', 'start': 167.28, 'duration': 4.56},
#  {'text': 'oh this one has green spots this time',
#   'start': 169.44,
#   'duration': 4.799},
#  {'text': 'okay that means no buried treasure',
#   'start': 171.84,
#   'duration': 5.28},
#  {'text': 'channel oh my gosh dude I can finally',
#   'start': 174.239,
#   'duration': 4.561},
#  {'text': 'get Brad here take take three of these',
#   'start': 177.12,
#   'duration': 4.44},
#  {'text': 'oh thank God uh oh and a shipwreck on',
#   'start': 178.8,
#   'duration': 3.26},
#  {'text': 'the mountain', 'start': 181.56, 'duration': 3.569},
#  {'text': '[Music]', 'start': 182.06, 'duration': 3.069},
#  {'text': 'I got so distracted I think this is',
#   'start': 186.56,
#   'duration': 4.78},
#  {'text': 'gonna become a reoccurring theme okay I',
#   'start': 189.42,
#   'duration': 3.78},
#  {'text': "know there's a buried treasure map chest",
#   'start': 191.34,
#   'duration': 4.94},
#  {'text': "here bro there's your iron Chief",
#   'start': 193.2,
#   'duration': 5.94},
#  {'text': "let's go thank you should we go find",
#   'start': 196.28,
#   'duration': 4.3},
#  {'text': 'another one wait did we ever check out',
#   'start': 199.14,
#   'duration': 4.5},
#  {'text': 'that room why stop I see gold uh oh',
#   'start': 200.58,
#   'duration': 5.04},
#  {'text': 'there is a chest there is a chest dude I',
#   'start': 203.64,
#   'duration': 7.2},
#  {'text': 'gotta sharpness five sword what yeah I',
#   'start': 205.62,
#   'duration': 7.44},
#  {'text': 'just got a block of obsidian wait how',
#   'start': 210.84,
#   'duration': 4.259},
#  {'text': 'many blocks we can enter the nether if',
#   'start': 213.06,
#   'duration': 5.25},
#  {'text': 'you have four one oh okay', 'start': 215.099, 'duration': 4.5},
#  {'text': '[Music]', 'start': 218.31, 'duration': 3.989},
#  {'text': 'the server was like even saying fishing',
#   'start': 219.599,
#   'duration': 5.341},
#  {'text': 'rod did you seriously wrong', 'start': 222.299, 'duration': 4.86},
#  {'text': 'yeah can you underwater fish these are',
#   'start': 224.94,
#   'duration': 3.359},
#  {'text': "the questions I don't know people need",
#   'start': 227.159,
#   'duration': 3.72},
#  {'text': 'to know Rick can you underwater wait I',
#   'start': 228.299,
#   'duration': 3.841},
#  {'text': 'have a texture pack that gets rid of the',
#   'start': 230.879,
#   'duration': 3.121},
#  {'text': "bottom hold on oh more coal I've been a",
#   'start': 232.14,
#   'duration': 3.36},
#  {'text': 'wonderful boy oh wait', 'start': 234.0, 'duration': 3.42},
#  {'text': "the berry treasure map you ready I'm",
#   'start': 235.5,
#   'duration': 4.379},
#  {'text': 'gonna test out underwater fishing',
#   'start': 237.42,
#   'duration': 6.679},
#  {'text': "we're excited the people are ready",
#   'start': 239.879,
#   'duration': 4.22},
#  {'text': 'wait it actually might work it actually',
#   'start': 244.62,
#   'duration': 3.66},
#  {'text': 'wait wait wait wait wait wait wait wait',
#   'start': 246.78,
#   'duration': 4.319},
#  {'text': "wait actually actually we've got so much",
#   'start': 248.28,
#   'duration': 4.379},
#  {'text': "junk at the surface already we're",
#   'start': 251.099,
#   'duration': 3.481},
#  {'text': "already polluting the ocean and we've",
#   'start': 252.659,
#   'duration': 4.441},
#  {'text': 'been here for five minutes right',
#   'start': 254.58,
#   'duration': 4.08},
#  {'text': 'but do you think I can fish like this',
#   'start': 257.1,
#   'duration': 3.3},
#  {'text': "it's some underwater air pockets so then",
#   'start': 258.66,
#   'duration': 5.419},
#  {'text': 'we could just fish underwater Oh my gosh',
#   'start': 260.4,
#   'duration': 3.679},
#  {'text': '[Applause]', 'start': 265.95, 'duration': 6.39},
#  {'text': "take the first fish dude I oh I don't",
#   'start': 268.5,
#   'duration': 5.699},
#  {'text': 'want that oh God that thing almost',
#   'start': 272.34,
#   'duration': 3.419},
#  {'text': "killed me earlier yeah I guess that's",
#   'start': 274.199,
#   'duration': 4.861},
#  {'text': 'true burn it burn it well how',
#   'start': 275.759,
#   'duration': 6.301},
#  {'text': 'water', 'start': 279.06, 'duration': 3.0},
#  {'text': 'so cursed after our minor food break we',
#   'start': 284.16,
#   'duration': 4.14},
#  {'text': 'were off to find some way to enter the',
#   'start': 286.68,
#   'duration': 3.12},
#  {'text': "nether oh there's a trident there's a",
#   'start': 288.3,
#   'duration': 3.959},
#  {'text': 'trident Dive Dive Dive Dive Dive Dive',
#   'start': 289.8,
#   'duration': 3.76},
#  {'text': 'go go go go go go go go', 'start': 292.259, 'duration': 4.981},
#  {'text': '[Music]', 'start': 293.56, 'duration': 4.76},
#  {'text': 'oh', 'start': 297.24, 'duration': 3.179},
#  {'text': "I found a cave I'm so like baffled but",
#   'start': 298.32,
#   'duration': 5.939},
#  {'text': 'like amazed oh I found the lava I heard',
#   'start': 300.419,
#   'duration': 5.161},
#  {'text': 'it yep do you know how to make a speed',
#   'start': 304.259,
#   'duration': 4.041},
#  {'text': 'portal chief', 'start': 305.58, 'duration': 2.72},
#  {'text': 'all right so I am going to enter the',
#   'start': 309.139,
#   'duration': 4.901},
#  {'text': "nether first I'm not I don't think we're",
#   'start': 312.419,
#   'duration': 3.181},
#  {'text': 'gonna enter the nether for the first',
#   'start': 314.04,
#   'duration': 5.82},
#  {'text': 'time baby yo oh my God', 'start': 315.6, 'duration': 8.48},
#  {'text': 'Rick this looks so cursed dude', 'start': 319.86, 'duration': 4.22},
#  {'text': "that's another man it's just another",
#   'start': 329.58,
#   'duration': 5.94},
#  {'text': "I don't know", 'start': 332.3, 'duration': 5.02},
#  {'text': 'the thing about this is the normal',
#   'start': 335.52,
#   'duration': 4.82},
#  {'text': 'nether wreck', 'start': 337.32, 'duration': 3.02},
#  {'text': 'forgot about that', 'start': 341.52, 'duration': 3.72},
#  {'text': 'um well uh should we try and find a',
#   'start': 342.84,
#   'duration': 4.799},
#  {'text': "Bastion let's try and find a bastard are",
#   'start': 345.24,
#   'duration': 5.24},
#  {'text': 'we just gonna beat the game', 'start': 347.639, 'duration': 4.821},
#  {'text': '[Music]', 'start': 350.48, 'duration': 4.54},
#  {'text': "oh wreck I'm gonna do it ready watch me",
#   'start': 352.46,
#   'duration': 4.72},
#  {'text': 'speed Bridge yep here we go', 'start': 355.02, 'duration': 4.019},
#  {'text': 'nice almost', 'start': 357.18, 'duration': 4.68},
#  {'text': "yeah hold on we almost got it we're",
#   'start': 359.039,
#   'duration': 5.401},
#  {'text': 'almost there just just hold on it now I',
#   'start': 361.86,
#   'duration': 5.64},
#  {'text': 'can speed Bridge yeah', 'start': 364.44, 'duration': 4.44},
#  {'text': "oh wait he's gonna get in the water",
#   'start': 367.5,
#   'duration': 3.06},
#  {'text': "that's never been a problem when I've",
#   'start': 368.88,
#   'duration': 3.36},
#  {'text': 'done this', 'start': 370.56, 'duration': 3.3},
#  {'text': 'oh look at my uh speed perching job',
#   'start': 372.24,
#   'duration': 3.36},
#  {'text': "that's pretty good yeah that's that",
#   'start': 373.86,
#   'duration': 3.96},
#  {'text': 'looks nice straight efficient you barely',
#   'start': 375.6,
#   'duration': 5.06},
#  {'text': 'used any blocks', 'start': 377.82, 'duration': 2.84},
#  {'text': 'yeah I think if we just see one we just',
#   'start': 391.699,
#   'duration': 5.981},
#  {'text': 'like run in the water honestly okay so I',
#   'start': 394.56,
#   'duration': 6.12},
#  {'text': 'just I have a question though huh how',
#   'start': 397.68,
#   'duration': 4.859},
#  {'text': 'much is the water gonna impede their',
#   'start': 400.68,
#   'duration': 3.15},
#  {'text': 'movement okay not a lot I guess',
#   'start': 402.539,
#   'duration': 3.421},
#  {'text': '[Laughter]', 'start': 403.83, 'duration': 3.27},
#  {'text': 'boom and then we have we have our',
#   'start': 405.96,
#   'duration': 2.4},
#  {'text': 'pickling trading dude I already got',
#   'start': 407.1,
#   'duration': 4.02},
#  {'text': "pearls let's go yo", 'start': 408.36, 'duration': 5.04},
#  {'text': "yo no it's hype we got fire resistance",
#   'start': 411.12,
#   'duration': 5.9},
#  {'text': "yeah well let's jump in the water",
#   'start': 413.4,
#   'duration': 7.68},
#  {'text': "let's go to silvery", 'start': 417.02, 'duration': 5.56},
#  {'text': 'foreign', 'start': 421.08, 'duration': 4.1},
#  {'text': '[Music]', 'start': 422.58, 'duration': 6.0},
#  {'text': 'I found another chest oh I got 16 golden',
#   'start': 425.18,
#   'duration': 5.76},
#  {'text': 'carrots', 'start': 428.58, 'duration': 2.36},
#  {'text': '[Music]', 'start': 433.89, 'duration': 5.07},
#  {'text': 'one bit down here', 'start': 435.919, 'duration': 6.461},
#  {'text': "well you'll live if you missed this",
#   'start': 438.96,
#   'duration': 5.6},
#  {'text': 'oh', 'start': 442.38, 'duration': 4.74},
#  {'text': "okay let's let's go find another",
#   'start': 444.56,
#   'duration': 4.72},
#  {'text': "Fortress psych We're not gonna find",
#   'start': 447.12,
#   'duration': 3.78},
#  {'text': 'another Fortress because we only have 10',
#   'start': 449.28,
#   'duration': 4.56},
#  {'text': 'pearls so we found a second bash there',
#   'start': 450.9,
#   'duration': 5.699},
#  {'text': 'is a uh lava lake right next to it so I',
#   'start': 453.84,
#   'duration': 4.32},
#  {'text': "don't I don't know how we're gonna be",
#   'start': 456.599,
#   'duration': 3.961},
#  {'text': 'able to do this Chief honestly', 'start': 458.16, 'duration': 5.4},
#  {'text': 'oh', 'start': 460.56, 'duration': 3.0},
#  {'text': 'that was whoa', 'start': 464.22, 'duration': 4.62},
#  {'text': 'dude look at this even with water',
#   'start': 466.46,
#   'duration': 4.239},
#  {'text': 'everywhere though the nether can still',
#   'start': 468.84,
#   'duration': 4.46},
#  {'text': 'be brutal', 'start': 470.699, 'duration': 2.601},
#  {'text': 'whoa whoa whoa', 'start': 473.4, 'duration': 4.44},
#  {'text': 'I got poison', 'start': 475.86, 'duration': 4.8},
#  {'text': 'that was really quick', 'start': 477.84, 'duration': 5.46},
#  {'text': 'um some of your stuff did Survive by',
#   'start': 480.66,
#   'duration': 4.379},
#  {'text': 'some of your stuff I mean the two',
#   'start': 483.3,
#   'duration': 3.48},
#  {'text': 'netherite scraps you have this whole',
#   'start': 485.039,
#   'duration': 3.421},
#  {'text': 'thing is gonna be you like taking me as',
#   'start': 486.78,
#   'duration': 3.419},
#  {'text': 'like I am the the clown or something',
#   'start': 488.46,
#   'duration': 4.38},
#  {'text': "don't be so sure about that Chief I'm",
#   'start': 490.199,
#   'duration': 3.9},
#  {'text': 'gonna die', 'start': 492.84, 'duration': 6.62},
#  {'text': "well if it's any consolation wreck um uh",
#   'start': 494.099,
#   'duration': 8.54},
#  {'text': "we're so bad dude", 'start': 499.46, 'duration': 6.04},
#  {'text': 'honestly I felt terrible after that loss',
#   'start': 502.639,
#   'duration': 4.661},
#  {'text': 'and it was so hard to get back where we',
#   'start': 505.5,
#   'duration': 5.899},
#  {'text': 'were run go go go go go', 'start': 507.3, 'duration': 6.299},
#  {'text': "but if there's one thing about me and",
#   'start': 511.399,
#   'duration': 4.421},
#  {'text': "chief we don't give up", 'start': 513.599, 'duration': 5.82},
#  {'text': "let's go all right uh", 'start': 515.82, 'duration': 4.54},
#  {'text': 'okay', 'start': 519.419, 'duration': 3.24},
#  {'text': '[Music]', 'start': 520.36, 'duration': 4.16},
#  {'text': 'just like that we were back where we',
#   'start': 522.659,
#   'duration': 3.781},
#  {'text': "left off I didn't fall into lava let's",
#   'start': 524.52,
#   'duration': 3.84},
#  {'text': 'go go go go go', 'start': 526.44, 'duration': 3.54},
#  {'text': "let's get the hairy heck out of here",
#   'start': 528.36,
#   'duration': 4.38},
#  {'text': "okay chief I've made it back do you have",
#   'start': 529.98,
#   'duration': 5.28},
#  {'text': 'a house okay oh my gosh we have a house',
#   'start': 532.74,
#   'duration': 6.0},
#  {'text': 'we uh you know houses are over a bit of',
#   'start': 535.26,
#   'duration': 5.88},
#  {'text': 'a stretch but you know we got it you',
#   'start': 538.74,
#   'duration': 3.48},
#  {'text': "know what we're missing though Chief",
#   'start': 541.14,
#   'duration': 3.42},
#  {'text': 'every underwater base has to have glass',
#   'start': 542.22,
#   'duration': 6.119},
#  {'text': 'windows I agree and maybe a ceiling',
#   'start': 544.56,
#   'duration': 6.24},
#  {'text': "yeah I guess it's dripping Hall so we",
#   'start': 548.339,
#   'duration': 3.901},
#  {'text': 'decided to build a second building to',
#   'start': 550.8,
#   'duration': 2.82},
#  {'text': 'get enchantments like depth Strider',
#   'start': 552.24,
#   'duration': 3.12},
#  {'text': 'which would make killing the dragon much',
#   'start': 553.62,
#   'duration': 3.86},
#  {'text': 'easier', 'start': 555.36, 'duration': 4.26},
#  {'text': 'I love how the equivalent of our',
#   'start': 557.48,
#   'duration': 4.06},
#  {'text': 'scaffolding is just randomly placed',
#   'start': 559.62,
#   'duration': 4.279},
#  {'text': 'doors', 'start': 561.54, 'duration': 2.359},
#  {'text': 'perks of building underwater finally we',
#   'start': 564.72,
#   'duration': 5.88},
#  {'text': 'have a dome dude', 'start': 568.08, 'duration': 5.04},
#  {'text': 'get domed boys that sounds inappropriate',
#   'start': 570.6,
#   'duration': 5.94},
#  {'text': "but yeah step Strider two let's go oh my",
#   'start': 573.12,
#   'duration': 4.68},
#  {'text': 'gosh I need to try this out I need to',
#   'start': 576.54,
#   'duration': 4.7},
#  {'text': 'try this out go for it', 'start': 577.8, 'duration': 3.44},
#  {'text': 'with our new gear we finally set out',
#   'start': 581.48,
#   'duration': 4.479},
#  {'text': 'into the deep and known in search of a',
#   'start': 584.04,
#   'duration': 3.239},
#  {'text': 'fortress oh', 'start': 585.959, 'duration': 3.481},
#  {'text': 'I think I spotted it Chief Heavies',
#   'start': 587.279,
#   'duration': 4.62},
#  {'text': "teddies okay all right we're heading",
#   'start': 589.44,
#   'duration': 4.64},
#  {'text': 'east', 'start': 591.899, 'duration': 2.181},
#  {'text': "I hear Blaze oh there's Blaze there's",
#   'start': 594.74,
#   'duration': 6.099},
#  {'text': "Blaze oh no Chief don't get lit on fire",
#   'start': 598.019,
#   'duration': 4.041},
#  {'text': 'oh', 'start': 600.839, 'duration': 4.081},
#  {'text': "yeah where's our Fire Res gosh dang it",
#   'start': 602.06,
#   'duration': 4.6},
#  {'text': 'if only we had like some water', 'start': 604.92, 'duration': 3.06},
#  {'text': 'everywhere', 'start': 606.66, 'duration': 4.64},
#  {'text': "because we don't have Fire Res", 'start': 607.98, 'duration': 3.32},
#  {'text': 'oh', 'start': 613.08, 'duration': 2.06},
#  {'text': "dude the police he's drowning oh my gosh",
#   'start': 615.42,
#   'duration': 6.9},
#  {'text': "that was so great okay so you're at one",
#   'start': 619.38,
#   'duration': 6.18},
#  {'text': 'blade spawner right yeah and oh sugar',
#   'start': 622.32,
#   'duration': 4.94},
#  {'text': 'plums did you hit them', 'start': 625.56, 'duration': 4.5},
#  {'text': 'or was that like a skeleton hopefully no',
#   'start': 627.26,
#   'duration': 6.579},
#  {'text': 'no no no no no I hit them oh okay so my',
#   'start': 630.06,
#   'duration': 6.12},
#  {'text': "stuff should be it's when you add the",
#   'start': 633.839,
#   'duration': 4.581},
#  {'text': 'other place', 'start': 636.18, 'duration': 2.24},
#  {'text': "um I'm just gonna break the spawner",
#   'start': 638.94,
#   'duration': 3.6},
#  {'text': "since we have another one dude a baby's",
#   'start': 640.38,
#   'duration': 5.639},
#  {'text': "got your shield no give him back I don't",
#   'start': 642.54,
#   'duration': 4.859},
#  {'text': 'know if I wanna I wanna mess with him',
#   'start': 646.019,
#   'duration': 3.841},
#  {'text': 'man babies are babies are tough oh my',
#   'start': 647.399,
#   'duration': 5.0},
#  {'text': "gosh there's nobody blame it oh my gosh",
#   'start': 649.86,
#   'duration': 7.5},
#  {'text': "oh my gosh okay I'm gonna leave I'm",
#   'start': 652.399,
#   'duration': 6.091},
#  {'text': 'Gonna Leave', 'start': 657.36, 'duration': 5.94},
#  {'text': '[Music]', 'start': 658.49, 'duration': 7.57},
#  {'text': "dude I have so many goodies I'm just",
#   'start': 663.3,
#   'duration': 5.159},
#  {'text': 'excited to see them 16 blaze rods 50',
#   'start': 666.06,
#   'duration': 5.88},
#  {'text': 'obsidian six Diamond 37 ancient debris',
#   'start': 668.459,
#   'duration': 6.841},
#  {'text': 'aprils oh my God 57 blocks of gold dude',
#   'start': 671.94,
#   'duration': 5.76},
#  {'text': "that's nuts okay I'm gonna measure eyes",
#   'start': 675.3,
#   'duration': 4.02},
#  {'text': 'and hopefully', 'start': 677.7, 'duration': 4.759},
#  {'text': 'pinpoint the stronghold', 'start': 679.32, 'duration': 3.139},
#  {'text': 'okay I have pinpointed the location of',
#   'start': 682.62,
#   'duration': 3.839},
#  {'text': 'the stronghold Chief I just needed some',
#   'start': 685.019,
#   'duration': 2.94},
#  {'text': "food and then I'm ready to rumble oh",
#   'start': 686.459,
#   'duration': 3.301},
#  {'text': "wait I have a fire aspect sword I'm",
#   'start': 687.959,
#   'duration': 4.5},
#  {'text': 'gonna cook fish underwater dude oh yeah',
#   'start': 689.76,
#   'duration': 4.519},
#  {'text': "that's the sword", 'start': 692.459, 'duration': 5.88},
#  {'text': "okay I'm hoping this is the right chunk",
#   'start': 694.279,
#   'duration': 6.221},
#  {'text': "all right I'm oh it is it is I guessed",
#   'start': 698.339,
#   'duration': 2.261},
#  {'text': 'it', 'start': 700.5, 'duration': 2.519},
#  {'text': '[Music]', 'start': 700.6, 'duration': 5.0},
#  {'text': "aha I made it unfortunately we didn't",
#   'start': 703.019,
#   'duration': 4.56},
#  {'text': 'have enough Eyes of Ender so back into',
#   'start': 705.6,
#   'duration': 2.87},
#  {'text': 'the Bastion', 'start': 707.579, 'duration': 2.461},
#  {'text': '[Music]', 'start': 708.47, 'duration': 3.549},
#  {'text': "uh let's just put them in a hole just in",
#   'start': 710.04,
#   'duration': 4.2},
#  {'text': 'case everybody else is like dead yeah oh',
#   'start': 712.019,
#   'duration': 5.221},
#  {'text': 'I found a brute oh yep run just run just',
#   'start': 714.24,
#   'duration': 5.159},
#  {'text': 'run wait Chief wait I have something I',
#   'start': 717.24,
#   'duration': 4.14},
#  {'text': "swear to God if it's a fire resistance",
#   'start': 719.399,
#   'duration': 4.5},
#  {'text': 'potion', 'start': 721.38, 'duration': 3.42},
#  {'text': 'um', 'start': 723.899, 'duration': 3.661},
#  {'text': 'um I got you cheese', 'start': 724.8, 'duration': 7.2},
#  {'text': 'I missed wait I missed I got another one',
#   'start': 727.56,
#   'duration': 9.26},
#  {'text': 'yeah I splashed this guy with fires',
#   'start': 732.0,
#   'duration': 7.38},
#  {'text': "there's a baby", 'start': 736.82, 'duration': 6.4},
#  {'text': "got him dude he's still 24 gold I'll be",
#   'start': 739.38,
#   'duration': 5.22},
#  {'text': 'picking up these oh I got another pro',
#   'start': 743.22,
#   'duration': 2.88},
#  {'text': 'trade wreck', 'start': 744.6, 'duration': 6.2},
#  {'text': "look out there's shoes on the road",
#   'start': 746.1,
#   'duration': 4.7},
#  {'text': 'thanks for entertaining me that was a',
#   'start': 753.72,
#   'duration': 4.08},
#  {'text': 'really poor joke but I appreciate you',
#   'start': 755.76,
#   'duration': 4.5},
#  {'text': "yeah I I didn't get it I'm actually very",
#   'start': 757.8,
#   'duration': 4.2},
#  {'text': 'excited to go to the end this will be so',
#   'start': 760.26,
#   'duration': 4.98},
#  {'text': "nice we're gonna get so much loot",
#   'start': 762.0,
#   'duration': 5.899},
#  {'text': 'what', 'start': 765.24, 'duration': 2.659},
#  {'text': "I just see you doing 360 says we're",
#   'start': 768.32,
#   'duration': 5.079},
#  {'text': 'going down', 'start': 771.48, 'duration': 3.9},
#  {'text': 'because at this point I decided to try',
#   'start': 773.399,
#   'duration': 4.081},
#  {'text': 'and zero cycle the dragon a very cool',
#   'start': 775.38,
#   'duration': 4.5},
#  {'text': "but risky way of killing it I'm actually",
#   'start': 777.48,
#   'duration': 5.159},
#  {'text': 'like getting nervous dude actually oh',
#   'start': 779.88,
#   'duration': 4.68},
#  {'text': "God yeah if you're getting nervous and",
#   'start': 782.639,
#   'duration': 3.841},
#  {'text': "it's getting me nervous okay I just",
#   'start': 784.56,
#   'duration': 5.12},
#  {'text': 'gotta not think about this', 'start': 786.48, 'duration': 3.2},
#  {'text': 'thank you all right coming in', 'start': 790.139, 'duration': 4.82},
#  {'text': 'foreign', 'start': 796.86, 'duration': 12.23},
#  {'text': '[Music]', 'start': 798.48, 'duration': 10.61},
#  {'text': '[Music]', 'start': 812.44, 'duration': 5.36},
#  {'text': 'I should have bailed oh my God this is',
#   'start': 815.3,
#   'duration': 4.9},
#  {'text': "weird dude it's flooded wait I just",
#   'start': 817.8,
#   'duration': 4.02},
#  {'text': 'finally had a moment to think about what',
#   'start': 820.2,
#   'duration': 3.12},
#  {'text': "I'm looking at here", 'start': 821.82, 'duration': 3.54},
#  {'text': "yeah you know how it's called The End",
#   'start': 823.32,
#   'duration': 6.12},
#  {'text': "Island Chief it's now legit an island oh",
#   'start': 825.36,
#   'duration': 5.82},
#  {'text': "okay I'm back in the end I'm back in the",
#   'start': 829.44,
#   'duration': 3.6},
#  {'text': "end okay chief you didn't make a",
#   'start': 831.18,
#   'duration': 3.599},
#  {'text': 'staircase out how did you get out of',
#   'start': 833.04,
#   'duration': 2.479},
#  {'text': 'here', 'start': 834.779, 'duration': 3.86},
#  {'text': 'come let me out come let me out',
#   'start': 835.519,
#   'duration': 5.56},
#  {'text': 'hey all right yeah just start grabbing',
#   'start': 838.639,
#   'duration': 3.64},
#  {'text': "your stuff I'll start tossing you",
#   'start': 841.079,
#   'duration': 3.541},
#  {'text': 'whatever I have', 'start': 842.279, 'duration': 4.68},
#  {'text': 'by running into the statue with you',
#   'start': 844.62,
#   'duration': 5.159},
#  {'text': "either way no you know I'm your",
#   'start': 846.959,
#   'duration': 7.801},
#  {'text': 'cameraman blow it up yeah take that yeah',
#   'start': 849.779,
#   'duration': 7.321},
#  {'text': 'make him hurt he', 'start': 854.76, 'duration': 6.6},
#  {'text': 'eat beds got it got it all this left',
#   'start': 857.1,
#   'duration': 6.72},
#  {'text': 'were those elytres okay well welcome to',
#   'start': 861.36,
#   'duration': 5.7},
#  {'text': 'the end I hope you brought some wood',
#   'start': 863.82,
#   'duration': 5.699},
#  {'text': 'oh thank God I do have wood okay I was',
#   'start': 867.06,
#   'duration': 4.98},
#  {'text': 'gonna say I had some wood if you lost it',
#   'start': 869.519,
#   'duration': 4.5},
#  {'text': "we're a bit screwed we need some boats",
#   'start': 872.04,
#   'duration': 4.5},
#  {'text': 'that I can provide would you like some',
#   'start': 874.019,
#   'duration': 5.401},
#  {'text': 'of the highest quality jungle boats a',
#   'start': 876.54,
#   'duration': 3.86},
#  {'text': 'man can provide', 'start': 879.42, 'duration': 2.479},
#  {'text': '[Music]', 'start': 880.4, 'duration': 6.22},
#  {'text': "oh whoa bro what what's that for oh did",
#   'start': 881.899,
#   'duration': 7.541},
#  {'text': 'I look at him or did you oh', 'start': 886.62, 'duration': 7.399},
#  {'text': "yeah we're about to get to the boats",
#   'start': 889.44,
#   'duration': 4.579},
#  {'text': 'dude this is so dope this is so sick',
#   'start': 896.72,
#   'duration': 7.419},
#  {'text': "dude what the heck you bet you've never",
#   'start': 900.899,
#   'duration': 5.94},
#  {'text': 'done this before I can say that with',
#   'start': 904.139,
#   'duration': 5.76},
#  {'text': 'certainty holy cow wreck oh Lando Lando',
#   'start': 906.839,
#   'duration': 6.541},
#  {'text': 'look at how many out there all right',
#   'start': 909.899,
#   'duration': 5.581},
#  {'text': "it's left oh and City NCD you know it's",
#   'start': 913.38,
#   'duration': 4.139},
#  {'text': 'kind of funny', 'start': 915.48, 'duration': 3.78},
#  {'text': 'yeah I chose from the end boats and',
#   'start': 917.519,
#   'duration': 4.201},
#  {'text': "we're in boats you know well yeah we're",
#   'start': 919.26,
#   'duration': 5.22},
#  {'text': "finally like we're getting in the boat",
#   'start': 921.72,
#   'duration': 4.46},
#  {'text': "that isn't in the water", 'start': 924.48, 'duration': 4.44},
#  {'text': 'careful try not to use the follow your',
#   'start': 926.18,
#   'duration': 5.019},
#  {'text': "dude they're all just accurate on you",
#   'start': 928.92,
#   'duration': 3.9},
#  {'text': "I'm just sniping them they don't even",
#   'start': 931.199,
#   'duration': 3.44},
#  {'text': 'care oh wait never mind', 'start': 932.82, 'duration': 7.04},
#  {'text': "let's go Diamonds oh chest plate",
#   'start': 934.639,
#   'duration': 5.221},
#  {'text': "it was a bit of a setback but it wasn't",
#   'start': 940.579,
#   'duration': 4.12},
#  {'text': 'all bad if we were low on food and while',
#   'start': 942.959,
#   'duration': 3.301},
#  {'text': 'I was waiting for cheap to get back I',
#   'start': 944.699,
#   'duration': 3.481},
#  {'text': 'fished for some more food plus we were',
#   'start': 946.26,
#   'duration': 4.5},
#  {'text': "so close to elytra's ah I'm flying",
#   'start': 948.18,
#   'duration': 5.339},
#  {'text': "fishing I'm flying fishing I'm fly",
#   'start': 950.76,
#   'duration': 6.259},
#  {'text': "fishing I'm literally fly fishing cheap",
#   'start': 953.519,
#   'duration': 6.18},
#  {'text': 'I got hit by a shulker and I was',
#   'start': 957.019,
#   'duration': 5.5},
#  {'text': 'levitating I was levitating while',
#   'start': 959.699,
#   'duration': 5.58},
#  {'text': 'fishing oh I think I see you', 'start': 962.519, 'duration': 6.841},
#  {'text': 'do you way off in the distance row row',
#   'start': 965.279,
#   'duration': 7.201},
#  {'text': 'row me wreck row me out the way do all',
#   'start': 969.36,
#   'duration': 4.919},
#  {'text': "the effort while I sit in back and don't",
#   'start': 972.48,
#   'duration': 4.2},
#  {'text': 'attract the Enderman you know the end',
#   'start': 974.279,
#   'duration': 4.74},
#  {'text': 'was cool we got the elytres finally but',
#   'start': 976.68,
#   'duration': 4.14},
#  {'text': "honestly that wasn't what we cared about",
#   'start': 979.019,
#   'duration': 3.901},
#  {'text': 'we went back to the old world and messed',
#   'start': 980.82,
#   'duration': 3.959},
#  {'text': 'around each getting tridents to propel',
#   'start': 982.92,
#   'duration': 3.419},
#  {'text': 'us through the water but I think the',
#   'start': 984.779,
#   'duration': 3.18},
#  {'text': 'coolest thing we did was get some',
#   'start': 986.339,
#   'duration': 4.201},
#  {'text': 'sponges and put them in the nether wait',
#   'start': 987.959,
#   'duration': 6.361},
#  {'text': 'chief sponges dry in the nether but the',
#   'start': 990.54,
#   'duration': 6.0},
#  {'text': 'nether is also full of water do you',
#   'start': 994.32,
#   'duration': 4.379},
#  {'text': 'think a sponge will dry in the nether or',
#   'start': 996.54,
#   'duration': 3.9},
#  {'text': 'wet in the nether this is like the hole',
#   'start': 998.699,
#   'duration': 4.26},
#  {'text': "is water wet conundrum right I'm gonna",
#   'start': 1000.44,
#   'duration': 6.24},
#  {'text': 'go with it is going to be dry okay and I',
#   'start': 1002.959,
#   'duration': 6.32},
#  {'text': 'have a theory', 'start': 1006.68, 'duration': 2.599},
#  {'text': "you won't believe what's happening dude",
#   'start': 1010.24,
#   'duration': 6.64},
#  {'text': 'what you just need to come to the Nether',
#   'start': 1013.579,
#   'duration': 5.88},
#  {'text': "and see this oh my gosh okay I'm on my",
#   'start': 1016.88,
#   'duration': 5.3},
#  {'text': 'way oh my gosh', 'start': 1019.459, 'duration': 2.721},
#  {'text': 'what the heck this is so cool', 'start': 1022.3, 'duration': 8.8},
#  {'text': 'I made a tent I made a tent I made a',
#   'start': 1026.799,
#   'duration': 7.601},
#  {'text': "tent underwater and that's the end of",
#   'start': 1031.1,
#   'duration': 5.219},
#  {'text': 'the video I really need to thank waffles',
#   'start': 1034.4,
#   'duration': 3.419},
#  {'text': 'are better for helping me code this',
#   'start': 1036.319,
#   'duration': 3.0},
#  {'text': 'whole thing I could not have done it',
#   'start': 1037.819,
#   'duration': 3.421},
#  {'text': 'without him and he was so helpful also',
#   'start': 1039.319,
#   'duration': 3.541},
#  {'text': "I'm still working on the armor trim",
#   'start': 1041.24,
#   'duration': 3.48},
#  {'text': "video it's just taking forever to mine",
#   'start': 1042.86,
#   'duration': 3.54},
#  {'text': "all of the diamonds so I figured I'd put",
#   'start': 1044.72,
#   'duration': 3.18},
#  {'text': 'this video out beforehand and then',
#   'start': 1046.4,
#   'duration': 3.36},
#  {'text': 'thanks to Dr Rat for coding a mod to',
#   'start': 1047.9,
#   'duration': 3.3},
#  {'text': 'help me see better underwater for this',
#   'start': 1049.76,
#   'duration': 3.96},
#  {'text': "video but that's pretty much all I got I",
#   'start': 1051.2,
#   'duration': 4.56},
#  {'text': "hope you guys have an epic day and I'll",
#   'start': 1053.72,
#   'duration': 5.48},
#  {'text': 'talk to you later peace', 'start': 1055.76, 'duration': 3.44},
#  {'text': '[Applause]', 'start': 1059.99, 'duration': 5.99},
#  {'text': '[Music]', 'start': 1060.08, 'duration': 8.959},
#  {'text': 'thank you', 'start': 1065.98, 'duration': 3.059}]
